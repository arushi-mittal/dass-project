# %%
import cv2
import glob

# %%
#lst = glob.glob("Frames/*.jpg"
path = "Frames/2/*.jpg"
lst1 = [filename.replace("\\","/") for filename in glob.glob(path)]

# %%
lst1 #= [e.replace('names','FolderFrames') for e in lst1]
# Out:
# ['Frames/2/2_frame1.jpg',
#  'Frames/2/2_frame10020.jpg',
#  'Frames/2/2_frame10080.jpg',
#  'Frames/2/2_frame10140.jpg',
#  'Frames/2/2_frame1020.jpg',
#  'Frames/2/2_frame10200.jpg',
#  'Frames/2/2_frame10260.jpg',
#  'Frames/2/2_frame10320.jpg',
#  'Frames/2/2_frame10380.jpg',
#  'Frames/2/2_frame10440.jpg',
#  'Frames/2/2_frame10500.jpg',
#  'Frames/2/2_frame10560.jpg',
#  'Frames/2/2_frame10620.jpg',
#  'Frames/2/2_frame10680.jpg',
#  'Frames/2/2_frame10740.jpg',
#  'Frames/2/2_frame1080.jpg',
#  'Frames/2/2_frame10800.jpg',
#  'Frames/2/2_frame10860.jpg',
#  'Frames/2/2_frame10920.jpg',
#  'Frames/2/2_frame10980.jpg',
#  'Frames/2/2_frame11040.jpg',
#  'Frames/2/2_frame11100.jpg',
#  'Frames/2/2_frame11160.jpg',
#  'Frames/2/2_frame11220.jpg',
#  'Frames/2/2_frame11280.jpg',
#  'Frames/2/2_frame11340.jpg',
#  'Frames/2/2_frame1140.jpg',
#  'Frames/2/2_frame11400.jpg',
#  'Frames/2/2_frame11460.jpg',
#  'Frames/2/2_frame11520.jpg',
#  'Frames/2/2_frame11580.jpg',
# ...

# %%
# no need to rotate in our case
# for flname in lst1:
#     img = cv2.imread(flname)
#     img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
#     cv2.imwrite(flname, img_rotate_90_counterclockwise)

# %%
# 1920 by 1080
for flname in lst1:
    img = cv2.imread(flname)
    
    if (img.shape[0] != 1080 and img.shape[1] != 1920):
        #print(flname)
        resized = cv2.resize(img, (1920,1080))
        cv2.imwrite(flname, resized)
    #resized = cv2.resize(img, dim

# %%
lst1
# Out:
# ['Frames/2/2_frame1.jpg',
#  'Frames/2/2_frame10020.jpg',
#  'Frames/2/2_frame10080.jpg',
#  'Frames/2/2_frame10140.jpg',
#  'Frames/2/2_frame1020.jpg',
#  'Frames/2/2_frame10200.jpg',
#  'Frames/2/2_frame10260.jpg',
#  'Frames/2/2_frame10320.jpg',
#  'Frames/2/2_frame10380.jpg',
#  'Frames/2/2_frame10440.jpg',
#  'Frames/2/2_frame10500.jpg',
#  'Frames/2/2_frame10560.jpg',
#  'Frames/2/2_frame10620.jpg',
#  'Frames/2/2_frame10680.jpg',
#  'Frames/2/2_frame10740.jpg',
#  'Frames/2/2_frame1080.jpg',
#  'Frames/2/2_frame10800.jpg',
#  'Frames/2/2_frame10860.jpg',
#  'Frames/2/2_frame10920.jpg',
#  'Frames/2/2_frame10980.jpg',
#  'Frames/2/2_frame11040.jpg',
#  'Frames/2/2_frame11100.jpg',
#  'Frames/2/2_frame11160.jpg',
#  'Frames/2/2_frame11220.jpg',
#  'Frames/2/2_frame11280.jpg',
#  'Frames/2/2_frame11340.jpg',
#  'Frames/2/2_frame1140.jpg',
#  'Frames/2/2_frame11400.jpg',
#  'Frames/2/2_frame11460.jpg',
#  'Frames/2/2_frame11520.jpg',
#  'Frames/2/2_frame11580.jpg',
# ...
